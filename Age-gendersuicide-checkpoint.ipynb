# %% [markdown]
# # Age-group and Gender based suicide rate analysis

# %%
# Function to insert data into MongoDB from python
import pandas as pd
from pymongo import MongoClient
import json

def mongoimport(csv_path, db_name, coll_name, db_url='localhost', db_port=27017):
    """ Imports a csv file at path csv_name to a mongo colection
    returns: count of the documants in the new collection
    """
    client = MongoClient(db_url, db_port)
    db = client[db_name]
    coll = db[coll_name]
    data = pd.read_csv(csv_path)
    payload = json.loads(data.to_json(orient='records'))
    #coll.remove()
    coll.insert_many(payload)
    print("record successfully inserted")

# %%
#Write the input data set into Mongo DB
#mongoimport("C:/Users/JAYA MENON/OneDrive - Livent Corporation/Documents/WHOCrudeSuicideRates_2021-07-16v1.csv/WHOCrudeSuicideRates_2021-07-16v1.csv","test01_db","input_table")

# %%
#print the collection from mongo DB
import pymongo
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["test01_db"]
col = db["input_table"]
x = col.find()
for data in x:
    print(data)
# Out:
# {'_id': ObjectId('626147a943d5b53d5b8449f2'), 'WHO Region Code': 'AMR', 'WHO Region': 'Americas', 'Country Code': 'ATG', 'Country': 'Antigua and Barbuda', 'Year': 2019, 'IsLatestYear': True, 'Sex': 'Both sexes', 'Age Group': '15-19 years', 'Crude suicide rates (per 100 000 population) (numeric)': 0.0, 'Crude suicide rates (per 100 000 population) (low estimation)': None, 'Crude suicide rates (per 100 000 population) (high estimation)': None, 'Crude suicide rates (per 100 000 population) (string)': '0'}
# ...

# %%
#read the data from Mongo DB into data frame
import pymongo
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["test01_db"]
col = db["input_table"]
test = db.input_table
df = pd.DataFrame(list(test.find()))
df
# Out:
#                             _id WHO Region Code             WHO Region  \
# 0      626147a943d5b53d5b8449f2             AMR               Americas
# 1      626147a943d5b53d5b8449f3             AMR               Americas
# 2      626147a943d5b53d5b8449f4             AMR               Americas
# 3      626147a943d5b53d5b8449f5             AMR               Americas
# 4      626147a943d5b53d5b8449f6             AMR               Americas
# ...                         ...             ...                    ...
# 17014  626147a943d5b53d5b848c68             AMR               Americas
# 17015  626147a943d5b53d5b848c69             EMR  Eastern Mediterranean
# 17016  626147a943d5b53d5b848c6a             WPR        Western Pacific
# 17017  626147a943d5b53d5b848c6b             WPR        Western Pacific
# 17018  626147a943d5b53d5b848c6c             EUR                 Europe
#
#       Country Code              Country  Year  IsLatestYear         Sex  \
# ...

# %%
df.columns  # get column names of data frame
# Out:
# Index(['_id', 'WHO Region Code', 'WHO Region', 'Country Code', 'Country',
#        'Year', 'IsLatestYear', 'Sex', 'Age Group',
#        'Crude suicide rates (per 100 000 population) (numeric)',
#        'Crude suicide rates (per 100 000 population) (low estimation)',
#        'Crude suicide rates (per 100 000 population) (high estimation)',
#        'Crude suicide rates (per 100 000 population) (string)'],
#       dtype='object')

# %%
df.isnull().any() # identify null value  present in the data frame
# Out:
# _id                                                               False
# WHO Region Code                                                   False
# WHO Region                                                        False
# Country Code                                                      False
# Country                                                           False
# Year                                                              False
# IsLatestYear                                                      False
# Sex                                                               False
# Age Group                                                         False
# Crude suicide rates (per 100 000 population) (numeric)            False
# Crude suicide rates (per 100 000 population) (low estimation)      True
# Crude suicide rates (per 100 000 population) (high estimation)     True
# Crude suicide rates (per 100 000 population) (string)             False
# dtype: bool

# %%
#df.dropna(inplace=True) # remove null values in the data frame

# %%
df.isnull().any()
# Out:
# _id                                                               False
# WHO Region Code                                                   False
# WHO Region                                                        False
# Country Code                                                      False
# Country                                                           False
# Year                                                              False
# IsLatestYear                                                      False
# Sex                                                               False
# Age Group                                                         False
# Crude suicide rates (per 100 000 population) (numeric)            False
# Crude suicide rates (per 100 000 population) (low estimation)      True
# Crude suicide rates (per 100 000 population) (high estimation)     True
# Crude suicide rates (per 100 000 population) (string)             False
# dtype: bool

# %%
#data cleaning # extract record with suicide rate greater than zero

print(df.shape[0])
df = df[df["Crude suicide rates (per 100 000 population) (numeric)"] > 0]
print(df.shape[0])
#df = df.loc[(df["Crude suicide rates (per 100 000 population) (numeric)"] != 0)]
# Out:
# 17019
# 16842

# %%
#df.groupby(["Country Code","Country","Year","Sex","Age Group"])[["Crude suicide rates (per 100 000 population) (numeric)"]].max()
# rank the records based on the suicide rate
import warnings
warnings.filterwarnings('ignore')
df["RANK"] = df.groupby(["Country Code","Country","Year","Sex"])["Crude suicide rates (per 100 000 population) (numeric)"].rank(method="dense", ascending=False)
df
# Out:
#                             _id WHO Region Code             WHO Region Country Code              Country  Year  IsLatestYear         Sex    Age Group  Crude suicide rates (per 100 000 population) (numeric)  Crude suicide rates (per 100 000 population) (low estimation)  Crude suicide rates (per 100 000 population) (high estimation) Crude suicide rates (per 100 000 population) (string)  RANK
# 140    626147a943d5b53d5b844a7e             AMR               Americas          BRB             Barbados  2019          True      Female     All Ages                                               0.32                                                    0.22                                                           0.45                                              0.32 [0.22 – 0.45]      2.0
# ...

# %%
#write the filtered record to the output file
df_01.to_csv("C:/Users/JAYA MENON/OneDrive - Livent Corporation/Documents/data_test/out_male.csv")
df_02.to_csv("C:/Users/JAYA MENON/OneDrive - Livent Corporation/Documents/data_test/out_female.csv")
df_03.to_csv("C:/Users/JAYA MENON/OneDrive - Livent Corporation/Documents/data_test/out_bothsex.csv")

# %%
df_01
# Out:
#                            _id WHO Region Code             WHO Region Country Code               Country  Year  IsLatestYear   Sex    Age Group  Crude suicide rates (per 100 000 population) (numeric)
# 419   626147a943d5b53d5b844b95             AMR               Americas          BRB              Barbados  2019          True  Male  45-54 years                                               1.48
# 641   626147a943d5b53d5b844c73             EMR  Eastern Mediterranean          SYR  Syrian Arab Republic  2019          True  Male    85+ years                                              10.02
# 762   626147a943d5b53d5b844cec             AMR               Americas          GRD               Grenada  2019          True  Male  65-74 years                                              10.53
# 802   626147a943d5b53d5b844d14             AMR               Americas          PER                  Peru  2019          True  Male    85+ years                                              10.75
# ...

# %%
# !pip3 install --upgrade psycopg2  #Library for Postgre SQL

# %%
# diving data frames according to gender
df_01.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)
df_02.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)
df_03.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)
df_01 = df_01[["Country","Year","Age Group","Sex","suicide_rate"]]
df_02 = df_02[["Country","Year","Age Group","Sex","suicide_rate"]]
df_03 = df_03[["Country","Year","Age Group","Sex","suicide_rate"]]

# %%
# table creation in post sql gre
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:DAP123@localhost:5432/age_gender')
df_01.to_sql('male_table', engine)
df_02.to_sql('female_table', engine)
df_03.to_sql('both_table', engine)

# %%
import psycopg2
dbconnection = engine.connect();

# %%
df_01 = pd.read_sql("select * from \"table_male\"", dbconnection);
#df_02 = pd.read_sql("select * from \"tab_female\"", dbconnection);
#df_03 = pd.read_sql("select * from \"tab_both\"", dbconnection);
pd.set_option('display.expand_frame_repr', False);
dbconnection.close();

# %%
df_01
# Out:
#                    Country  Year    Age Group   Sex  suicide_rate
# 419               Barbados  2019  45-54 years  Male          1.48
# 641   Syrian Arab Republic  2019    85+ years  Male         10.02
# 762                Grenada  2019  65-74 years  Male         10.53
# 802                   Peru  2019    85+ years  Male         10.75
# 813                Algeria  2019    85+ years  Male         10.80
# ...                    ...   ...          ...   ...           ...
# 7679                Mexico  2017     All Ages  Male          9.79
# 7680                Malawi  2017     All Ages  Male          9.84
# 7682                  Chad  2017     All Ages  Male          9.90
# 7683            Costa Rica  2017     All Ages  Male          9.92
# 7684                 China  2017     All Ages  Male          9.92
#
# [544 rows x 5 columns]

# %%
##suicide rate for Male
import seaborn as sns
from matplotlib import pyplot as plt
df_01.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)
df_01.columns
df_01 = df_01.sort_values(['suicide_rate'], ascending=[False])
df_01_x = df_01.head(10)
sns.barplot(x="suicide_rate", y="Country", hue="Age Group", data=df_01_x,
              palette = sns.xkcd_palette(["windows blue", "amber",  "raspberry"])).set(title='Top countries with Male suicide rate')
plt.show()

# %%
#suicide rate for Female
df_02.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)
df_02.columns
df_02 = df_02.sort_values(['suicide_rate'], ascending=[False])
df_02_x = df_02.head(10)
sns.barplot(x="suicide_rate", y="Country", hue="Age Group", data=df_02_x, 
              palette = sns.xkcd_palette(["windows blue", "amber",  "raspberry"])).set(title='Top countries with Female suicide rate')
plt.show()

# %%
#suicide rate for Both sexes
df_03.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)
df_03.columns
df_03 = df_03.sort_values(['suicide_rate'], ascending=[False])
df_03_x = df_03.head(10)
sns.barplot(x="suicide_rate", y="Country", hue="Age Group", data=df_03_x, 
              palette = sns.xkcd_palette(["windows blue", "amber",  "raspberry"])).set(title='Top countries with Both Sexes suicide rate')
plt.show()

# %%
df_gender_2017 = pd.concat([df_01, df_02, df_03])

# %%
df_gender_2017 = df_gender_2017.loc[(df["Year"] == 2017)]

# %%
# data frame for 2018 
df_gender_2018 = pd.concat([df_01, df_02, df_03])
df_gender_2018 = df_gender_2018.loc[(df["Year"] == 2018)]
df_gender_2018
# Out:
#                                Country  Year Age Group         Sex  suicide_rate
# 6692                           Lesotho  2018  All Ages        Male        124.60
# 7039                            Guyana  2018  All Ages        Male         61.63
# 6999                          Eswatini  2018  All Ages        Male         54.06
# 6956                          Kiribati  2018  All Ages        Male         48.23
# 6955                         Lithuania  2018  All Ages        Male         47.47
# ...                                ...   ...       ...         ...           ...
# 6620             Sao Tome and Principe  2018  All Ages  Both sexes          1.46
# 6608  Saint Vincent and the Grenadines  2018  All Ages  Both sexes          1.00
# 6595                          Barbados  2018  All Ages  Both sexes          0.62
# 6592               Antigua and Barbuda  2018  All Ages  Both sexes          0.38
# 6590                           Grenada  2018  All Ages  Both sexes          0.29
#
# ...

# %%
#data frame for 2019
df_gender_2019 = pd.concat([df_01, df_02, df_03])
df_gender_2019 = df_gender_2019.loc[(df["Year"] == 2019)]
df_gender_2019[["Age Group"]]
df_gender_2019
# Out:
#                                Country  Year    Age Group         Sex  suicide_rate
# 5586                        Mozambique  2019    85+ years        Male        646.00
# 5556                           Lesotho  2019    85+ years        Male        600.70
# 5077                     Côte d’Ivoire  2019    85+ years        Male        518.20
# 5055          Central African Republic  2019    85+ years        Male        507.00
# 4642                          Zimbabwe  2019    85+ years        Male        450.80
# ...                                ...   ...          ...         ...           ...
# 5175                           Jamaica  2019    85+ years  Both sexes          6.02
# 4745                           Grenada  2019  65-74 years  Both sexes          5.17
# 3645               Antigua and Barbuda  2019  55-64 years  Both sexes          3.71
# 3494                          Barbados  2019  75-84 years  Both sexes          3.39
# ...

# %%
#gender based plot for 2017
df_gender_2017 = df_gender_2017.head(10)
sns.barplot(x="suicide_rate", y="Country", hue="Sex", data=df_gender_2017, 
              palette = sns.xkcd_palette(["windows blue", "amber",  "raspberry"])).set(title='Gender based suicide rate for year 2017')
plt.show()

# %%
#gender based 2018 suicide rate
df_gender_2018 = df_gender_2018.head(10)
sns.barplot(x="suicide_rate", y="Country", hue="Sex", data=df_gender_2018, 
              palette = sns.xkcd_palette(["windows blue", "amber",  "raspberry"])).set(title='Gender based suicide rate for year 2018')
plt.show()

# %%
#Gender based suicide rate 2019
df_gender_2019_both = df_gender_2019
df_gender_2019 = df_gender_2019.head(10)
sns.barplot(x="suicide_rate", y="Country", hue="Sex", data=df_gender_2019, 
              palette = sns.xkcd_palette(["windows blue", "amber",  "raspberry"])).set(title='Gender based suicide rate for year 2019')
plt.show()

# %%
#Suicide Based on Year And Age
color=['red','green','blue','orange','gray','#222111']
plt.figure(figsize=(16,12))
sns.swarmplot(x='Age Group',y='Crude suicide rates (per 100 000 population) (numeric)',hue='Year',data=df.head(300),palette=color)
plt.title("Suicide Based On The Year And Age Group")
plt.xticks(rotation=90)
plt.ylabel("Suicide Number")
# Out:
# Text(0, 0.5, 'Suicide Number')

# %%
df_suicide_rate2019

# %%
df_suicide_rate2019 = df_suicide_rate2019.reset_index(drop=True)

# %%
# writing output of 2019 data into csv for collaborating with Dataset-2,Dataset-1 and Dataset-4
df_suicide_rate2019.to_csv("C:/Users/JAYA MENON/OneDrive - Livent Corporation/Documents/data_test/out_2019new.csv",index=False)

# %%
df[df["Year"]==2016]

# %%
df_suicide_rate2016 = df[df["Year"]==2016]

# %%
df_suicide_rate2016.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)
df_suicide_rate2016 = df_suicide_rate2016 [["Country","Year","suicide_rate"]]

# %%
df_suicide_rate2016

# %%
df_suicide_rate2016

# %%
df_suicide_rate2016.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)

# %%
df_suicide_rate2016 = df_suicide_rate2016.reset_index(drop=True)

# %%
df_suicide_rate2016

# %%
# writing output of 2016 data into csv for collaborating with Dataset-2 and Dataset-1
df_suicide_rate2016.to_csv("C:/Users/JAYA MENON/OneDrive - Livent Corporation/Documents/data_test/out_2016.csv",index=False)

# %%
df_gender_2019_both
# Out:
#                                Country  Year    Age Group         Sex  suicide_rate
# 5586                        Mozambique  2019    85+ years        Male        646.00
# 5556                           Lesotho  2019    85+ years        Male        600.70
# 5077                     Côte d’Ivoire  2019    85+ years        Male        518.20
# 5055          Central African Republic  2019    85+ years        Male        507.00
# 4642                          Zimbabwe  2019    85+ years        Male        450.80
# ...                                ...   ...          ...         ...           ...
# 5175                           Jamaica  2019    85+ years  Both sexes          6.02
# 4745                           Grenada  2019  65-74 years  Both sexes          5.17
# 3645               Antigua and Barbuda  2019  55-64 years  Both sexes          3.71
# 3494                          Barbados  2019  75-84 years  Both sexes          3.39
# ...

# %%
#df_suicide_rateplot2019 = df_gender_2019 [["Country","Sex","Year","suicide_rate","Age Group"]]
#df_gender_2019_both
df_suicide_rateplot2019 = df_gender_2019_both [["Country","Sex","Year","suicide_rate","Age Group"]]

# %%
df_suicide_rateplot2019
# Out:
#                                Country         Sex  Year  suicide_rate    Age Group
# 5586                        Mozambique        Male  2019        646.00    85+ years
# 5556                           Lesotho        Male  2019        600.70    85+ years
# 5077                     Côte d’Ivoire        Male  2019        518.20    85+ years
# 5055          Central African Republic        Male  2019        507.00    85+ years
# 4642                          Zimbabwe        Male  2019        450.80    85+ years
# ...                                ...         ...   ...           ...          ...
# 5175                           Jamaica  Both sexes  2019          6.02    85+ years
# 4745                           Grenada  Both sexes  2019          5.17  65-74 years
# 3645               Antigua and Barbuda  Both sexes  2019          3.71  55-64 years
# 3494                          Barbados  Both sexes  2019          3.39  75-84 years
# ...

# %%
#Pie chart for Gender and Age group for 2019 
f, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,6))
grouped_sex = df_suicide_rateplot2019.groupby("Sex")['suicide_rate'].sum()
x = grouped_sex.index.tolist()
y = grouped_sex.values.tolist()
ax1.pie(y,labels=x, autopct='%1.1f%%', shadow=True, startangle=90, pctdistance=0.7, textprops={'fontsize': 16})
grouped_age = df.groupby("Age Group")['Crude suicide rates (per 100 000 population) (numeric)'].sum()
x = grouped_age.index.tolist()
y = grouped_age.values.tolist()
ax2.pie(y,labels=x, autopct='%1.1f%%', shadow=True, startangle=140, pctdistance=0.7, textprops={'fontsize': 16})
f.suptitle("SUICIDE DISTRIBUTION in GENDER and AGE GROUPS FOR 2019", fontsize=18, color = 'k')
f.subplots_adjust(top=0.92)
plt.tight_layout()
plt.show()

# %%
# creating dummy variable for correlation matrix
df_dummies = pd.get_dummies(df['Sex'])
#del df_dummies[df_dummies.columns[-1]]
df_new = pd.concat([df, df_dummies], axis=1)
del df_new['Sex']
df_new
# Out:
#                             _id WHO Region Code             WHO Region Country Code              Country  Year  IsLatestYear    Age Group  Crude suicide rates (per 100 000 population) (numeric)  Crude suicide rates (per 100 000 population) (low estimation)  Crude suicide rates (per 100 000 population) (high estimation) Crude suicide rates (per 100 000 population) (string)  RANK  Both sexes  Female  Male
# 140    626147a943d5b53d5b844a7e             AMR               Americas          BRB             Barbados  2019          True     All Ages                                               0.32                                                    0.22                                                           0.45                                              0.32 [0.22 – 0.45]      2.0           0       1     0
# ...

# %%
# Plotting correlation matrix of suicide rate with Male,Female and Both sexes
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#df1 = df[['Country', 'Sex', 'Crude suicide rates (per 100 000 population) (numeric)']]

df_new.rename(columns = {'Crude suicide rates (per 100 000 population) (numeric)':'suicide_rate'}, inplace = True)
df1 = df_new[['Both sexes', 'Female', 'Male', 'suicide_rate']]
f, ax = plt.subplots(figsize=(10, 8))
corr = df1.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax).set(title='Correlation Matrix for Suicide rate of Gender')
#df.corr()
# Out:
# [Text(0.5, 1.0, 'Correlation Matrix for Suicide rate of Gender')]

# %%
grouped_sex
# Out:
# Sex
# Both sexes    11030.51
# Female         5192.83
# Male          22351.14
# Name: suicide_rate, dtype: float64

# %%
# cat plot based on age group and suicide rate
from numpy import sum
import warnings
warnings.filterwarnings('ignore')
sns.catplot('Sex','Crude suicide rates (per 100 000 population) (numeric)',hue='Age Group',col='Year',data=df.head(1000),kind='bar',col_wrap=3,estimator=sum)
#Also you can try this. It gives you all countries suicide scores in diffrent ages
'''
from numpy import sum
sns.catplot('age','suicides_no',hue='sex',col='country',data=data,kind='bar',col_wrap=3,estimator=sum)
'''
# Out:
# "\nfrom numpy import sum\nsns.catplot('age','suicides_no',hue='sex',col='country',data=data,kind='bar',col_wrap=3,estimator=sum)\n"
